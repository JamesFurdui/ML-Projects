# %%
import numpy as np
import os

# %% [markdown]
# Load previous X_train and X_test data that was saved in ''cv_img_classification_v1'' and reshape it into a vector.

# %%
X_train = np.load("numpy_data/X_train.npy")
X_test = np.load("numpy_data/X_test.npy")
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))

# %% [markdown]
# **Load Y_train and Y_test**

# %%
y_train = np.load("numpy_data/y_train.npy")
y_test = np.load("numpy_data/y_test.npy")
# Out:
# array([0, 0, 0, ..., 1, 1, 1], shape=(8005,))

# %%
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8005, 196608)
# X_test shape: (2023, 196608)
# y_train shape: (8005,)
# y_test shape: (2023,)

# %% [markdown]
# **Normalize X values**

# %%
# Do not recompute if possible. Std takes 2 minutes to compute
mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

# %% [markdown]
# Change mean and std data-type into uint8

# %%
mean = mean.astype('uint8')
std = std.astype('uint8')

# %%
X_train = (X_train - mean) // std
X_test = (X_test - mean) // std

# %%
from softmax_function import *
from linear_classifier import *
import time
softmax = Softmax()

tic = time.time()
softmax.train(X_train, y_train, learning_rate=1e-7, num_iters=2500, reg=2.5e4, verbose=True)
toc = time.time()

print(f"Training took {toc - tic} seconds")
# Out:
# iteration 0 / 2500: loss 9882.231543
